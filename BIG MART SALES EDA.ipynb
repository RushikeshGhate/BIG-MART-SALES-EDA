# %%
import pandas as pd
# ^^^ pyforest auto-imports - don't write above this line
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as st
# Out:
# C:\Users\ASUS\Anaconda3\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
train_set=pd.read_csv('train_bms.csv')
train_set.head(5)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
test_set=pd.read_csv('test_bms.csv')
test_set.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDW58       20.750          Low Fat         0.007565  Snack Foods
# 1           FDW14        8.300              reg         0.038428        Dairy
# 2           NCN55       14.600          Low Fat         0.099575       Others
# 3           FDQ58        7.315          Low Fat         0.015388  Snack Foods
# 4           FDY38          NaN          Regular         0.118599        Dairy
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  107.8622            OUT049                       1999      Medium
# 1   87.3198            OUT017                       2007         NaN
# 2  241.7538            OUT010                       1998         NaN
# 3  155.0340            OUT017                       2007         NaN
# 4  234.2300            OUT027                       1985      Medium
#
#   Outlet_Location_Type        Outlet_Type
# ...

# %%
train_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
train_set.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
#Item_Weight and  Outlet_Size

# %%
test_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5681 entries, 0 to 5680
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            5681 non-null   object
#  1   Item_Weight                4705 non-null   float64
#  2   Item_Fat_Content           5681 non-null   object
#  3   Item_Visibility            5681 non-null   float64
#  4   Item_Type                  5681 non-null   object
#  5   Item_MRP                   5681 non-null   float64
#  6   Outlet_Identifier          5681 non-null   object
#  7   Outlet_Establishment_Year  5681 non-null   int64
#  8   Outlet_Size                4075 non-null   object
#  9   Outlet_Location_Type       5681 non-null   object
#  10  Outlet_Type                5681 non-null   object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 488.3+ KB

# %%
test_set.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                   976
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  1606
# Outlet_Location_Type            0
# Outlet_Type                     0
# dtype: int64

# %%
train_set['Data']=1
test_set['Data']=0
test_set['Item_Outlet_Sales']=np.nan

# %%
df=pd.concat([train_set,test_set],ignore_index=True,sort=False)

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
df.tail()
# Out:
#       Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 14199           FDB58         10.5          Regular         0.013496
# 14200           FDD47          7.6          Regular         0.142991
# 14201           NCO17         10.0          Low Fat         0.073529
# 14202           FDJ26         15.3          Regular         0.000000
# 14203           FDU37          9.5          Regular         0.104720
#
#                 Item_Type  Item_MRP Outlet_Identifier  \
# 14199         Snack Foods  141.3154            OUT046
# 14200       Starchy Foods  169.1448            OUT018
# 14201  Health and Hygiene  118.7440            OUT045
# 14202              Canned  214.6218            OUT017
# 14203              Canned   79.7960            OUT045
#
#        Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 14199                       1997       Small               Tier 1
# 14200                       2009      Medium               Tier 3
# ...

# %%
df.shape
# Out:
# (14204, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14204 entries, 0 to 14203
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            14204 non-null  object
#  1   Item_Weight                11765 non-null  float64
#  2   Item_Fat_Content           14204 non-null  object
#  3   Item_Visibility            14204 non-null  float64
#  4   Item_Type                  14204 non-null  object
#  5   Item_MRP                   14204 non-null  float64
#  6   Outlet_Identifier          14204 non-null  object
#  7   Outlet_Establishment_Year  14204 non-null  int64
#  8   Outlet_Size                10188 non-null  object
#  9   Outlet_Location_Type       14204 non-null  object
#  10  Outlet_Type                14204 non-null  object
#  11  Item_Outlet_Sales          8523 non-null   float64
#  12  Data                       14204 non-null  int64
# ...

# %%
df.Item_Identifier.value_counts()
# Out:
# NCX41    10
# FDT25    10
# FDU15    10
# FDN21    10
# FDQ12    10
#          ..
# FDR51     7
# FDM52     7
# FDL50     7
# FDM50     7
# NCL42     7
# Name: Item_Identifier, Length: 1559, dtype: int64

# %%
ids=[]
for i in df.Item_Identifier:
    ids.append(i[:2])

# %%
df['Cat_ID']=ids

# %%
df.Cat_ID.value_counts()
# Out:
# FD    10201
# NC     2686
# DR     1317
# Name: Cat_ID, dtype: int64

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
df.Item_Weight.isnull().sum()
# Out:
# 2439

# %%
df.Outlet_Size.isnull().sum()
# Out:
# 4016

# %%
#Here We are replacing our Null Values with Mean of Item Weight grouped with Item_Identifier

# %%
df['Item_Weight']=df.groupby('Item_Identifier')['Item_Weight'].transform(lambda x:x.fillna(x.mean()))

# %%
df.Item_Weight.isnull().sum()
# Out:
# 0

# %%
df.Outlet_Size.value_counts()
# Out:
# Medium    4655
# Small     3980
# High      1553
# Name: Outlet_Size, dtype: int64

# %%
df.Outlet_Location_Type.value_counts()
# Out:
# Tier 3    5583
# Tier 2    4641
# Tier 1    3980
# Name: Outlet_Location_Type, dtype: int64

# %%
pd.crosstab([df.Outlet_Size,df.Outlet_Type],df.Outlet_Location_Type)
# Out:
# Outlet_Location_Type           Tier 1  Tier 2  Tier 3
# Outlet_Size Outlet_Type
# High        Supermarket Type1       0       0    1553
# Medium      Supermarket Type1    1550       0       0
#             Supermarket Type2       0       0    1546
#             Supermarket Type3       0       0    1559
# Small       Grocery Store         880       0       0
#             Supermarket Type1    1550    1550       0

# %%
df.loc[(df.Outlet_Location_Type=='Tier 1') & (df.Outlet_Type=='Supermarket Type1'),'Outlet_Size']='Medium'

# %%
df.loc[(df.Outlet_Location_Type=='Tier 1') & (df.Outlet_Type=='Grocery Store'),'Outlet_Size'] ='Small' #

# %%
df.loc[(df.Outlet_Location_Type=='Tier 2') & (df.Outlet_Type=='Supermarket Type1'),'Outlet_Size']='Small'

# %%
df.loc[(df.Outlet_Location_Type=='Tier 3') & (df.Outlet_Type=='Supermarket Type2'),'Outlet_Size']='Medium'

# %%
df.loc[(df.Outlet_Location_Type=='Tier 3') & (df.Outlet_Type=='Supermarket Type3'),'Outlet_Size']='Medium'

# %%
df.loc[(df.Outlet_Location_Type=='Tier 3') & (df.Outlet_Type=='Supermarket Type1'),'Outlet_Size']='High'

# %%
df.loc[(df.Outlet_Location_Type=='Tier 3') & (df.Outlet_Type=='Grocery Store'),'Outlet_Size'] ='Small'

# %%
df[df.Outlet_Size.isnull()]
# Out:
# Empty DataFrame
# Columns: [Item_Identifier, Item_Weight, Item_Fat_Content, Item_Visibility, Item_Type, Item_MRP, Outlet_Identifier, Outlet_Establishment_Year, Outlet_Size, Outlet_Location_Type, Outlet_Type, Item_Outlet_Sales, Data, Cat_ID]
# Index: []

# %%
df.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                     0
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                     0
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales            5681
# Data                            0
# Cat_ID                          0
# dtype: int64

# %%
df.Outlet_Size.isnull().sum()
# Out:
# 0

# %%
df.Item_Fat_Content.value_counts()
# Out:
# Low Fat    8485
# Regular    4824
# LF          522
# reg         195
# low fat     178
# Name: Item_Fat_Content, dtype: int64

# %%
df.Item_Fat_Content=df.Item_Fat_Content.replace(['reg','LF','low fat'],['Regular','Low Fat','Low Fat'])

# %% [markdown]
# # OR

# %% [markdown]
# def fatcont(a):
#     if a=='LF' or a=='low fat':
#         a='Low Fat'
#     elif a=='reg':
#         a='Regular'
#     return a

# %% [markdown]
# df.Item_Fat_Content=df.Item_Fat_Content.apply(fatcont)

# %%
df.Item_Fat_Content.value_counts()
# Out:
# Low Fat    9185
# Regular    5019
# Name: Item_Fat_Content, dtype: int64

# %%
test = df[df.Item_Outlet_Sales.isna()]

# %%
df=df.drop(['Item_Identifier','Outlet_Identifier','Cat_ID'],axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-54-7b4b2c7272f9> in <module>
# ----> 1 df=df.drop(['Item_Identifier','Outlet_Identifier','Cat_ID'],axis=1)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3995             level=level,
#    3996             inplace=inplace,
# -> 3997             errors=errors,
#    3998         )
#    3999
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# ...

# %%
train=df[0:8523]
train
# Out:
#       Item_Weight Item_Fat_Content  Item_Visibility              Item_Type  \
# 0           9.300          Low Fat         0.016047                  Dairy
# 1           5.920          Regular         0.019278            Soft Drinks
# 2          17.500          Low Fat         0.016760                   Meat
# 3          19.200          Regular         0.000000  Fruits and Vegetables
# 4           8.930          Low Fat         0.000000              Household
# ...           ...              ...              ...                    ...
# 8518        6.865          Low Fat         0.056783            Snack Foods
# 8519        8.380          Regular         0.046982           Baking Goods
# 8520       10.600          Low Fat         0.035186     Health and Hygiene
# 8521        7.210          Regular         0.145221            Snack Foods
# 8522       14.800          Low Fat         0.044878            Soft Drinks
#
# ...

# %%
df_new=pd.get_dummies(train)

# %%
df_new
# Out:
#       Item_Weight  Item_Visibility  Item_MRP  Outlet_Establishment_Year  \
# 0           9.300         0.016047  249.8092                       1999
# 1           5.920         0.019278   48.2692                       2009
# 2          17.500         0.016760  141.6180                       1999
# 3          19.200         0.000000  182.0950                       1998
# 4           8.930         0.000000   53.8614                       1987
# ...           ...              ...       ...                        ...
# 8518        6.865         0.056783  214.5218                       1987
# 8519        8.380         0.046982  108.1570                       2002
# 8520       10.600         0.035186   85.1224                       2004
# 8521        7.210         0.145221  103.1332                       2009
# 8522       14.800         0.044878   75.4670                       1997
#
#       Item_Outlet_Sales  Data  Item_Fat_Content_Low Fat  \
# ...

# %%
test=test.drop('Item_Outlet_Sales',axis=1)

# %%
X=train.drop('Item_Outlet_Sales',axis=1)
y=train.Item_Outlet_Sales

# %%
X.shape,y.shape
# Out:
# ((8523, 10), (8523,))

# %%
test.shape
# Out:
# (5681, 10)

# %%
df.head()
# Out:
#    Item_Weight Item_Fat_Content  Item_Visibility              Item_Type  \
# 0         9.30          Low Fat         0.016047                  Dairy
# 1         5.92          Regular         0.019278            Soft Drinks
# 2        17.50          Low Fat         0.016760                   Meat
# 3        19.20          Regular         0.000000  Fruits and Vegetables
# 4         8.93          Low Fat         0.000000              Household
#
#    Item_MRP  Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0  249.8092                       1999      Medium               Tier 1
# 1   48.2692                       2009      Medium               Tier 3
# 2  141.6180                       1999      Medium               Tier 1
# 3  182.0950                       1998       Small               Tier 3
# 4   53.8614                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales  Data
# 0  Supermarket Type1          3735.1380     1
# ...
